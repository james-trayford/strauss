# %%
# install the styles branch for now
# !pip install git+https://github.com/james-trayford/strauss.git@styles

# %% [markdown]
# ## Style-Based Sonification

# %%
# %reload_ext autoreload 
# %autoreload 2
# %matplotlib inline
import strauss
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(80)
y =  np.sin(x/2)
z = 0.1*x**2 - x - 5 
plt.plot(x,y)
plt.show()
plt.plot(x,z)

# %%
current_soni = strauss.sonify(x, y, style='flute_vibrato')

# %%
strauss.display()

# %%
np.log10()

# %%
x = np.arange(5,12,1)

# %%
rm -rf /Users/james/Library/Caches/strauss/

# %%
getattr(sources, 'Objects')()

# %%
ls -harlt /Users/james/Library/Caches/strauss/flute.sf2

# %%
ls ~/Documents/Code/strauss_dev/src/strauss/generator.py

# %%
from strauss.generator import Sampler

# %%
Sampler('/Users/james/Downloads/Persa.sf2')
