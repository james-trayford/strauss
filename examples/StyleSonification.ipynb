# %% [markdown]
# ## Style-Based Sonification

# %%
# %reload_ext autoreload 
# %autoreload 2
# %matplotlib inline
import strauss
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(80)
y =  np.sin(x/2)
plt.plot(x,y)

# %%
soni = strauss.sonify(y, style='theremin')

# %%
strauss.display()

# %%
np.log10()

# %%
x = np.arange(5,12,1)

# %%
getattr(sources, 'Objects')()
